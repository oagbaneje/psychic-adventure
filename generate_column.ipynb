# %%
import pandas as pd

risk_rating = pd.read_excel('risk_rating.xlsx')

col_names = ["Economic and Financial situation",
             "Leverage",
             "Profitability",
             "Cash flows",
             "Ownership Structure",
             "Management Quality",
             "Promptness/Willingness to Pay",
             "Strength of Sponsors",
             "Credit Bureau Report",
             "Sector Business",
             "Industry properties and future prospects",
             "Linkage of purpose to authorized business",
             "Routine of purpose to Borrower",
             "Borrower's financial contribution to Purpose (%)",
             "Justification of request",
             "Duration of facility",
             "Liquidity constraint implication to CBG",
             "Cashflow exclusive to CBG",
             "Viable primary source of repayment",
             "Existence of viable secondary means of repayment (not collateral)",
             "Outcome"
]

print(risk_rating)
# Out:
#     Unnamed: 0  CREDIT RISK RATING  Unnamed: 2           Unnamed: 3  \
# 0          NaN                 NaN         NaN                  NaN
# 1          NaN                 NaN         NaN                  NaN
# 2          NaN                 1.0         NaN  OBLIGOR RISK RATING
# 3          NaN                 NaN         NaN                  NaN
# 4          NaN                 NaN         NaN                  NaN
# 5          NaN                 NaN         NaN                    1
# 6          NaN                 NaN         NaN                  NaN
# 7          NaN                 NaN         NaN                  NaN
# 8          NaN                 NaN         NaN                  NaN
# 9          NaN                 NaN         NaN                    2
# 10         NaN                 NaN         NaN                  NaN
# 11         NaN                 NaN         NaN                  NaN
# 12         NaN                 NaN         NaN                  NaN
# ...
